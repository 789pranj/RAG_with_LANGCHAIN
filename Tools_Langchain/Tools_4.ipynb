# %%
from langchain_core.tools import tool

# %%
@tool
def add_numbers(a: float, b: float) -> float:
    """Adds two numbers together."""
    return a + b

@tool
def multiply_numbers(a: float, b: float) -> float:
    """Multiplies two numbers together."""
    return a * b

# %%
class MathToolsKit:
    def get_tools(self):
        return [add_numbers, multiply_numbers]

# %%
tools_kit = MathToolsKit()
tools = tools_kit.get_tools()
tools
# Out:
# [StructuredTool(name='add_numbers', description='Adds two numbers together.', args_schema=<class 'langchain_core.utils.pydantic.add_numbers'>, func=<function add_numbers at 0x000001BEF662F240>),
#  StructuredTool(name='multiply_numbers', description='Multiplies two numbers together.', args_schema=<class 'langchain_core.utils.pydantic.multiply_numbers'>, func=<function multiply_numbers at 0x000001BEF662EFC0>)]
