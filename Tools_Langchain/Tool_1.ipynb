# %%
from langchain_core.tools import tool

# %%
@tool
def add_numbers(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b

# %%
result = add_numbers.invoke({"a": 5, "b": 10})
result
# Out:
# 15

# %%
print(add_numbers.name)
print(add_numbers.description)
print(add_numbers.args)
print(add_numbers.args_schema.model_json_schema())
# Out:
# add_numbers
# Add two numbers.
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
# {'description': 'Add two numbers.', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'add_numbers', 'type': 'object'}
